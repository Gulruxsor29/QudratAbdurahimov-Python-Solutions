# %%
#if1
a =int(input(" berilgan sonni kiriting:"))
if ( a >= 0 ):
    print(a+1)
else:
    print(a)
# Out:
#  berilgan sonni kiriting: 2
# 3

# %%
#if2
a =int(input(" berilgan sonni kiriting:"))
if ( a >= 0 ):
    print(a+1)
else:
    print(a-2)
# Out:
#  berilgan sonni kiriting: -2
# -4

# %%
#if3
a =int(input(" berilgan sonni kiriting:"))
if ( a > 0):
    print(a+1)
elif (a == 0):
    print("a=10")
else:
    print(a-2)
# Out:
#  berilgan sonni kiriting: -3
# -5

# %%
#if4
a =int(input("1-sonni kiriting:"))
b =int(input("2-sonni kiriting:"))
c =int(input("3-sonni kiriting:"))
m=0
if a > 0 :
    m=m+1
if b > 0:
    m=m+1
if c > 0:
    m=m+1
print(m)
# Out:
# 1-sonni kiriting: -1
# 2-sonni kiriting: 2
# 3-sonni kiriting: 3
# 2

# %%
#if5
a =int(input("1-sonni kiriting:"))
b =int(input("2-sonni kiriting:"))
c =int(input("3-sonni kiriting:"))
m=0
n=0
if a > 0 :
    m=m+1
else:
    n=n+1
if b > 0:
    m=m+1
else:
    n=n+1
if c > 0:
    m=m+1
else:
    n=n+1
print(m ,n)
# Out:
# 1-sonni kiriting: 2
# 2-sonni kiriting: -2
# 3-sonni kiriting: 1
# 2 1

# %%
#if6
a =int(input(" 1-sonni kiriting:"))
b =int(input(" 2-sonni kiriting:"))
if a > b :
    print(a, " soni " , b,"dan katta")
else:
    print(b, " soni " , a,"dan katta")
# Out:
#  1-sonni kiriting: 2
#  2-sonni kiriting: 1
# 2  soni  1 dan katta

# %%
#if7
a =int(input(" 1-sonni kiriting:"))
b =int(input(" 2-sonni kiriting:"))
if a < b :
    print(" 1-son kichik")
else:
    print("2-son kichik")
# Out:
#  1-sonni kiriting: 4
#  2-sonni kiriting: 1
# 2-son kichik

# %%
#if8
a =int(input(" 1-sonni kiriting:"))
b =int(input(" 2-sonni kiriting:"))
if a > b :
    print( a , "soni katta")
else:
    print( a, "soni kichik")
if b > a :
    print(b , "soni katta")
else: 
    print(b , "soni kichik")
# Out:
#  1-sonni kiriting: 4
#  2-sonni kiriting: 2
# 4 soni katta
# 2 soni kichik

# %%
#if9
a =int(input(" 1-sonni kiriting:"))
b =int(input(" 2-sonni kiriting:"))
a,b = b,a
print(a , b)
# Out:
#  1-sonni kiriting: 3
#  2-sonni kiriting: 2
# 2 3

# %%
#if10
a =int(input(" 1-sonni kiriting:"))
b =int(input(" 2-sonni kiriting:"))
if a == b :
    print(0)
else:
    print(a+b)
# Out:
#  1-sonni kiriting: 2
#  2-sonni kiriting: 2
# 0

# %%
#if11
a =int(input(" 1-sonni kiriting:"))
b =int(input(" 2-sonni kiriting:"))
if a == b :
    print(0)
elif a>b:
    print(a)
else:
    print(b)
# Out:
#  1-sonni kiriting: 1
#  2-sonni kiriting: 3
# 3

# %%
#if12
a =int(input(" 1-sonni kiriting:"))
b =int(input(" 2-sonni kiriting:"))
c =int(input(" 3-sonni kiriting:"))
if a > b and a > c :
    print(a, "eng katta son")
elif b > a and b > c:
    print(b,  "eng katta son")
else:
    print(c, "eng katta son")
# Out:
#  1-sonni kiriting: 3
#  2-sonni kiriting: 4
#  3-sonni kiriting: 1
# 4 eng katta son

# %%
#if13
a =int(input(" 1-sonni kiriting:")) #3  2
b =int(input(" 2-sonni kiriting:"))#2   1
c =int(input(" 3-sonni kiriting:"))#1   3
if a > b > c :
    print(b, "o'rtacha son")
elif b > a  > c:
    print(a,  "o'rtacha son")
elif b > c > a:
    print(c,  "o'rtacha son")
else:
    print(c, "o'rtacha son")
# Out:
#  1-sonni kiriting: 1
#  2-sonni kiriting: 2
#  3-sonni kiriting: 3
# 3 o'rtacha son

# %%
#if14
a =int(input(" 1-sonni kiriting:")) #3  2
b =int(input(" 2-sonni kiriting:"))#2   1
c =int(input(" 3-sonni kiriting:"))#1   3
if a > b and a > c :
    print(a, "eng katta son")
elif b > a and b > c:
    print(b,  "eng katta son")
else:
    print(c, "eng katta son")
if a < b and a < c :
    print(a, "eng kichik son")
elif b < a and b < c:
    print(b,  "eng katta son")
else:
    print(c, "eng katta son")
# Out:
#  1-sonni kiriting: 1
#  2-sonni kiriting: 2
#  3-sonni kiriting: 3
# 3 eng katta son
# 1 eng kichik son

# %%
#if15
a = int(input(" 1-sonni kiriting:"))
b =int(input("2-sonni kiriting:"))
c =int(input("3-sonni kiriting:"))
if b+c < a+b > a+c :
    print(a+b)
elif a+b < b+c > a+c :
    print(b+c)
elif b+c < a+c > a+b :
    print(a+c)
# Out:
#  1-sonni kiriting: 1
# 2-sonni kiriting: 2
# 3-sonni kiriting: 3
# 5

# %%
#if16
A = float(input(" 1-sonni kiriting:"))
B =float(input("2-sonni kiriting:"))
C =float(input("3-sonni kiriting:"))
if A < B < C :
    print(A*2, B*2, C*2)
else:
    print(A*(-1), B*(-1), C*(-1))
# Out:
#  1-sonni kiriting: 3
# 2-sonni kiriting: 2
# 3-sonni kiriting: 1
# -3.0 -2.0 -1.0

# %%
#if17
A =float(input(" 1-sonni kiriting:"))
B =float(input("2-sonni kiriting:"))
C =float(input("3-sonni kiriting:"))
if A < B < C :
    print(A*2, B*2, C*2)
elif C < B < A :
        print(A*2, B*2, C*2)
else:
    print(A*(-1), B*(-1), C*(-1))
# Out:
#  1-sonni kiriting: 15
# 2-sonni kiriting: 2
# 3-sonni kiriting: 6
# -15.0 -2.0 -6.0

# %%
#if18
a = int(input(" 1-sonni kiriting:"))
b =int(input("2-sonni kiriting:"))
c =int(input("3-sonni kiriting:"))
if a==b and a != c :
    print(c, "=> 3-son")
elif a==c and a != b :
    print(b, "=> 2-son")
elif b==c and b != a:
    print(a, "=> 1-son")
else:
    print("shartga mos emas")
# Out:
#  1-sonni kiriting: 1
# 2-sonni kiriting: 2
# 3-sonni kiriting: 3
# shartga mos emas

# %%
#if19
a = int(input(" 1-sonni kiriting:"))
b =int(input("2-sonni kiriting:"))
c =int(input("3-sonni kiriting:"))
d =int(input("4-sonni kiriting:"))
if a==b and a==c and a!= d :
    print(d, "=> 4-son")
elif a==b and a==d and  a!=c :
    print(c, "=> 3-son")
elif b==c and b==d and b!=a:
    print(a, "=> 1-son")
elif d==c and d==a and  d!=b:
    print(b, "=> 2-son")
else:
    print("shartga mos emas")
# Out:
#  1-sonni kiriting: 1
# 2-sonni kiriting: 2
# 3-sonni kiriting: 1
# 4-sonni kiriting: 2
# shartga mos emas

# %%
#if20
a = int(input(" 1-sonni kiriting:"))
b =int(input("2-sonni kiriting:"))
c =int(input("3-sonni kiriting:"))
if abs(a-b) < abs(a-c):
    print("eng yaqin son:", b)
else:
    print("eng yaqin son:", c)
# Out:
#  1-sonni kiriting: 2
# 2-sonni kiriting: 6
# 3-sonni kiriting: 1
# eng yaqin son: 1

# %%
#if21
x =int(input(" berilgan x nuqtani kiriting:"))
y =int(input("berilgan y nuqtani kiriting:"))
if y == 0 and x == 0:
    print(0)
elif x==0:
    print(2)
elif y==0:
    print(1)
elif x!=0 and y!=0:
    print("nuqta kordinatalari mavjud")
# Out:
#  berilgan x nuqtani kiriting: 0
# berilgan y nuqtani kiriting: 1
# 2

# %%
#if22
x =int(input(" berilgan x nuqtani kiriting:"))
y =int(input("berilgan y nuqtani kiriting:"))
x!=0 ,y!=0
if x>0 and y>0 :
    print("1-chorak")
elif x<0 and y>0 :
    print("2-chorak")
elif x<0 and y<0 :
    print ("3-chorak")
elif x>0 and y<0 :
    print("4-chorak")
else:
    print("xatolik yuz berdi")
# Out:
#  berilgan x nuqtani kiriting: 0
# berilgan y nuqtani kiriting: 0
# xatolik yuz berdi

# %%
#if23
import math
a = int(input(" 1-sonni kiriting:"))
b =int(input("2-sonni kiriting:"))
c =int(input("3-sonni kiriting:"))
if x
# Out:
#  1-sonni kiriting: 1
# 2-sonni kiriting: 2
# 3-sonni kiriting: 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 8
#       6 x = abs(a-c)
#       7 y = abs(a-b)
# ----> 8 t = abs(d-b)
#       9 x == t
#      10 d = abs(a-c) + b
#
# NameError: name 'd' is not defined

# %%
#if24
import math
x =float(input("berilgan sonni kiriting:"))
if x > 0 :
    fx = 2*math.sin(x)
    print(fx)
elif x <= 0 :
    fx = x-6
    print(fx)
# Out:
# berilgan sonni kiriting: 0
# -6.0

# %%
#if25
import math
x =float(input("berilgan sonni kiriting:")) #x=3
if x > 2 or x < -2 :
    fx = 2*x
    print(fx)
else:
    fx = -3*x
    print(fx)
# Out:
# berilgan sonni kiriting: 1
# -3.0

# %%
#if26
x =float(input("berilgan sonni kiriting:"))
if x <= 0 :
    fx = -x
    print(fx)
elif 0 < x <2 :
    fx = x**2
    print
elif x >= 2 :
    fx = 4
    print(fx)
# Out:
# berilgan sonni kiriting: 1

# %%
#if27
x =float(input("berilgan sonni kiriting:"))
if x < 0 :
    fx = 0
    print(fx)
elif 0 < x <2 :
    fx = x**2
    print
elif x >= 2 :
    fx = 4
    print(fx)

# %%
#if28
y =int(input("yilni kiriting:"))
if y % 4 == 0 :
    print(y ,"=> bu yilda 366 kun mavjud")
else:
    print(y , "=> bu yilda 365 kun mavjud")
# Out:
# yilni kiriting: 2004
# 2004 bu yilda 366 kun mavjud

# %%
#if29
x =int(input("berilgan sonni kiriting:"))
if x > 0  and x%2 == 0:
    print("berilgan son musbat juft son")
elif x > 0 and x%2 != 0:
    print("berilgan son musbat toq son")
elif x < 0  and x%2 == 0:
    print("berilgan son manfiy juft son")
elif x < 0 and x%2 != 0:
    print("berilgan son manfiy toq son")
elif x == 0 :
    print("berilgan son 0 ga teng")
# Out:
# berilgan sonni kiriting: 7
# berilgan son musbat toq son

# %%
#if30
x =int(input("berilgan sonni kiriting:"))
if x < 10 :
    print(x,"=> bir xonali son")
elif x < 100 :
    print(x, "=> ikki xonali son")
elif x < 1000:
    print(x, "=> uch xonali son")
else:
    print( "1 - 999 oraliqda son kiriting!")
# Out:
# berilgan sonni kiriting: 1234
# 1234 1 - 999 oraliqda son kiriting!
